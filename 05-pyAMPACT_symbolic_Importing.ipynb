# %% [markdown]
# <a href="https://colab.research.google.com/github/jcdevaney/pyAMPACTtutorials/blob/main/05-pyAMPACT_symbolic_Importing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>pyAMPACT Importing Symbolic Data</h1>

# %%
# !git clone https://github.com/jcdevaney/pyAMPACTtutorials.git
# !pip install crim_intervals
from IPython.utils import io
print('Importing libraries...')
with io.capture_output() as captured:
    # !pip install --upgrade pandas
    # !pip install -i https://test.pypi.org/simple/ --no-deps pyampact==0.4.7
    import pyampact
# Out:
# fatal: destination path 'pyAMPACTtutorials' already exists and is not an empty directory.
# Requirement already satisfied: crim_intervals in /usr/local/lib/python3.10/dist-packages (2.0.16)
# Requirement already satisfied: altair==5.2.0 in /usr/local/lib/python3.10/dist-packages (from crim_intervals) (5.2.0)
# Requirement already satisfied: certifi==2020.12.5 in /usr/local/lib/python3.10/dist-packages (from crim_intervals) (2020.12.5)
# Requirement already satisfied: chardet==4.0.0 in /usr/local/lib/python3.10/dist-packages (from crim_intervals) (4.0.0)
# Requirement already satisfied: h11==0.14.0 in /usr/local/lib/python3.10/dist-packages (from crim_intervals) (0.14.0)
# Requirement already satisfied: httpcore==1.0.2 in /usr/local/lib/python3.10/dist-packages (from crim_intervals) (1.0.2)
# Requirement already satisfied: httpx==0.26.0 in /usr/local/lib/python3.10/dist-packages (from crim_intervals) (0.26.0)
# Requirement already satisfied: idna==3.1 in /usr/local/lib/python3.10/dist-packages (from crim_intervals) (3.1)
# Requirement already satisfied: ipython<8.0,>=7.23.1 in /usr/local/lib/python3.10/dist-packages (from crim_intervals) (7.34.0)
# Requirement already satisfied: joblib==1.0.1 in /usr/local/lib/python3.10/dist-packages (from crim_intervals) (1.0.1)
# Requirement already satisfied: jsonschema==3.2 in /usr/local/lib/python3.10/dist-packages (from crim_intervals) (3.2.0)
# Requirement already satisfied: lxml==5.1.0 in /usr/local/lib/python3.10/dist-packages (from crim_intervals) (5.1.0)
# Requirement already satisfied: more-itertools==8.7.0 in /usr/local/lib/python3.10/dist-packages (from crim_intervals) (8.7.0)
# Requirement already satisfied: music21==8.3.0 in /usr/local/lib/python3.10/dist-packages (from crim_intervals) (8.3.0)
# Requirement already satisfied: numpy<2.0.0,>=1.20.2 in /usr/local/lib/python3.10/dist-packages (from crim_intervals) (1.25.2)
# Requirement already satisfied: pandas>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from crim_intervals) (2.2.1)
# Requirement already satisfied: plotly==5.18.0 in /usr/local/lib/python3.10/dist-packages (from crim_intervals) (5.18.0)
# Requirement already satisfied: plotly-express==0.4.1 in /usr/local/lib/python3.10/dist-packages (from crim_intervals) (0.4.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from crim_intervals) (15.0.1)
# Requirement already satisfied: python-dateutil==2.8.2 in /usr/local/lib/python3.10/dist-packages (from crim_intervals) (2.8.2)
# Requirement already satisfied: python-louvain==0.16 in /usr/local/lib/python3.10/dist-packages (from crim_intervals) (0.16)
# Requirement already satisfied: pytz==2021.1 in /usr/local/lib/python3.10/dist-packages (from crim_intervals) (2021.1)
# Requirement already satisfied: pyvis==0.1.9 in /usr/local/lib/python3.10/dist-packages (from crim_intervals) (0.1.9)
# Requirement already satisfied: requests==2.31.0 in /usr/local/lib/python3.10/dist-packages (from crim_intervals) (2.31.0)
# Requirement already satisfied: rfc3986==1.4.0 in /usr/local/lib/python3.10/dist-packages (from crim_intervals) (1.4.0)
# Requirement already satisfied: seaborn==0.11.2 in /usr/local/lib/python3.10/dist-packages (from crim_intervals) (0.11.2)
# Requirement already satisfied: six==1.16.0 in /usr/local/lib/python3.10/dist-packages (from crim_intervals) (1.16.0)
# Requirement already satisfied: sniffio==1.2.0 in /usr/local/lib/python3.10/dist-packages (from crim_intervals) (1.2.0)
# Requirement already satisfied: statsmodels==0.14.1 in /usr/local/lib/python3.10/dist-packages (from crim_intervals) (0.14.1)
# Requirement already satisfied: textdistance==4.2.1 in /usr/local/lib/python3.10/dist-packages (from crim_intervals) (4.2.1)
# Requirement already satisfied: verovio==4.1.0 in /usr/local/lib/python3.10/dist-packages (from crim_intervals) (4.1.0)
# Requirement already satisfied: webcolors==1.11.1 in /usr/local/lib/python3.10/dist-packages (from crim_intervals) (1.11.1)
# Requirement already satisfied: xlsxwriter==3.0.2 in /usr/local/lib/python3.10/dist-packages (from crim_intervals) (3.0.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from altair==5.2.0->crim_intervals) (3.1.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from altair==5.2.0->crim_intervals) (24.0)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair==5.2.0->crim_intervals) (0.12.1)
# Requirement already satisfied: typing-extensions>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from altair==5.2.0->crim_intervals) (4.10.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx==0.26.0->crim_intervals) (3.7.1)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema==3.2->crim_intervals) (23.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema==3.2->crim_intervals) (0.20.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from jsonschema==3.2->crim_intervals) (67.7.2)
# Requirement already satisfied: jsonpickle in /usr/local/lib/python3.10/dist-packages (from music21==8.3.0->crim_intervals) (3.0.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from music21==8.3.0->crim_intervals) (3.7.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly==5.18.0->crim_intervals) (8.2.3)
# Requirement already satisfied: scipy>=0.18 in /usr/local/lib/python3.10/dist-packages (from plotly-express==0.4.1->crim_intervals) (1.11.4)
# Requirement already satisfied: patsy>=0.5 in /usr/local/lib/python3.10/dist-packages (from plotly-express==0.4.1->crim_intervals) (0.5.6)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from python-louvain==0.16->crim_intervals) (3.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests==2.31.0->crim_intervals) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests==2.31.0->crim_intervals) (2.0.7)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython<8.0,>=7.23.1->crim_intervals) (0.19.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython<8.0,>=7.23.1->crim_intervals) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython<8.0,>=7.23.1->crim_intervals) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython<8.0,>=7.23.1->crim_intervals) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython<8.0,>=7.23.1->crim_intervals) (3.0.43)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython<8.0,>=7.23.1->crim_intervals) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython<8.0,>=7.23.1->crim_intervals) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython<8.0,>=7.23.1->crim_intervals) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython<8.0,>=7.23.1->crim_intervals) (4.9.0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.2.0->crim_intervals) (2024.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython<8.0,>=7.23.1->crim_intervals) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->altair==5.2.0->crim_intervals) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->music21==8.3.0->crim_intervals) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->music21==8.3.0->crim_intervals) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->music21==8.3.0->crim_intervals) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->music21==8.3.0->crim_intervals) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->music21==8.3.0->crim_intervals) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->music21==8.3.0->crim_intervals) (3.1.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython<8.0,>=7.23.1->crim_intervals) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<8.0,>=7.23.1->crim_intervals) (0.2.13)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx==0.26.0->crim_intervals) (1.2.0)
# Importing libraries...

# %%
piece = pyampact.Score('/content/pyAMPACTtutorials/test_files/O_Virgo_Miserere.krn')
# Out:
# 	Detected and imported these spine types:
# 		 cdata-rdiss

# %% [markdown]
# That message lets you know which spine types you can request from .getSpines(). So now lets look at the dissonance analysis as a pandas dataframe:

# %%
rdiss = piece.getSpines('cdata-rdiss')
rdiss
# Out:
#       Voice Part-2 Part-3
#
# 6.0     NaN    NaN      q
# 9.0     NaN    NaN      p
# 11.0    NaN    NaN      p
# 14.0      q    NaN    NaN
# 20.0      g      s      g
# 29.0      p    NaN    NaN
# 37.0      P    NaN      P
# 59.0      P    NaN    NaN
# 67.0    NaN    NaN      P
# 71.0      a      e    NaN
# 75.0    NaN      k      P
# 77.0      P    NaN    NaN
# 79.0    NaN      P      P
# 81.0      e    NaN    NaN
# 85.0      p    NaN    NaN
# 87.0    NaN      P    NaN
# 90.0      q      q    NaN
# 107.0     P    NaN      P
# 109.0   NaN      n    NaN
# 111.0   NaN      P    NaN
# 113.0     p    NaN    NaN
# 115.0   NaN    NaN      c
# 125.0   NaN      p    NaN
# 154.0     b    NaN    NaN
# 162.0     b    NaN    NaN
# 166.0     v    NaN    NaN
# 179.0     P    NaN    NaN
# 188.0     s      g      g
# 221.0   NaN      p    NaN
# 225.0   NaN      n    NaN
# 245.0   NaN      p    NaN
# 249.0   NaN      p    NaN
# 255.0   NaN      P      P
# 265.0   NaN      P    NaN
# 270.0     w    NaN    NaN
# 279.0     n      n    NaN
# 281.0     p      p    NaN
# 283.0     p      p    NaN
# 287.0     e    NaN    NaN
# 293.0   NaN    NaN      P
# 295.0   NaN      P    NaN
# 305.0   NaN      n    NaN
# 313.0     p    NaN      P
# 315.0   NaN      P    NaN
# 318.0   NaN      Q    NaN
# 325.0   NaN    NaN      p
# 332.0     s      g      g
# 345.0     P    NaN    NaN
# 353.0     p      p    NaN
# 356.0     s      g      g

# %% [markdown]
# THIS NEEDS TO BE CONVERTED TO TEXT AND COMMENTS
#
# This notebook demonstrates how to use pyAMPACT with Humdrum. By "Humdrum" we are referring to the whole Humdrum ecosystem of analysis tools including humlib and the Verovio Humdrum Viewer. On its own, pyAMPACT already supports .krn as a symbolic notation file type for both importing and exporting/converting files. So this notebook goes beyond that and explains how to integrate Humdrum analysis tools into a pyAMPACT workflow.
#
#
# As a practical example, we get Renaissance dissonance analysis from the humlib dissonant tool. We then use pyAMPACT see which of the dissonance types correlate with various observed audio phenomena in a recording of the same piece. Since the two main components of this workflow are distributed in the Humdrum and pyAMPACT toolkits, the only way to realize this workflow is by combining these otherwise separate tools.
#
#
# Now let's get the score and analysis data. The critical thing here is that **the Humdrum analysis must be in the same .krn file as the score itself**. So in addition to having as many **kern spines as there are voices in the piece, the krn file should have at least one spine of analysis data. As a reference, there are several special spine types that we have dedicated methods for reading in as pandas dataframes in pyAMPACT. This table shows which pyAMPACT Score object methods to use to get each given .krn file spine type:
#
#
# | Spine Type | pyAMPACT Methods |
# |----------|----------|
# | **kern | .notes(), .midiPitches() |
# | **text | .lyrics() |
# | **dyanm | .dynamics() |
# | **harm | .harm(), .harmKeys(), .romanNumeral()|
# | **function | .functions() |
# | **chord | .chords() |
# | **cdata | .cdata() |
# | Any other spine type | .getSpines('name_of_spine_type') |
#
#
# In this notebook we're using .getSpines() to get `**cdata-rdiss` spine data into a score-time aligned pandas dataframe. We're using .getSpines because it's the generic spine importer pyAMPACT exposes for any spine types not explicitly listed in the table above.
#
#
# Humdrum's Renaissance dissonance classification tool is part of humlib and is also accessible on the Verovio Humdrum Viewer. You can go to any Renaissance score, then type "dissonant" in the text box and hit return. Then press the `+` button to the right of the text box to compile the filter which will put the analysis labels in their own spines in the .krn file. This is what that looks like for Obrecht's [Kyrie, Missa Ave regina celorum](https://verovio.humdrum.org/?file=jrp/Obr/Obr1002a-Missa_Ave_regina_celorum-Kyrie.krn).
#
#
#
#
# Alternatively you can add `!!!filter: dissonant` to the top of the .krn file on the left side of the score and then press`alt + c` to compile the filter (`option + c` on a mac). Then you can copy the full text and save it as your .krn file. Still another option is to use Humdrum from the terminal to create your score with analysis.
#
#
# Now that we have this file saved somewhere, let's import it with pyAMPACT. Notice how the `**cdata-rdiss` spines are detected on import and you get prompted with this message "Detected and imported these spine types: **cdata-rdiss"

# %% [markdown]
# <h2> Import a file for use in CRIM<h2>

# %%
import crim_intervals as crim

# %%
# CRIM only supports URL-based file importing
pyamp_piece = pyampact.Score('/content/pyAMPACTtutorials/test_files/O_Virgo_Miserere.krn')

crim_piece = crim.main_objs.Crimport('')
# Out:
# 	Detected and imported these spine types:
# 		 cdata-rdiss
#
# Import of  failed, please check your file, path, or url.

# %% [markdown]
# Use CRIM's Cadential Voice Function analysis, .cvfs() and then convert this piece into an MEI file that contains these CVF annotations using pyAMPACT. S
#
# CRIM's CVF dataframe can be treated as if it's a pyAMPACT dataframe without any special treatment as long as the dataframe's index to be time-aligned and for the columnar index to be voice names.
#
# In the couple of cases, CRIM dataframes differ from this structure (for example .cadences() has different columns and .presentationTypes() has a different index and columns). You can still work with this CRIM data in pyAMPACT in these cases, they just require some basic restructuring of the CRIM dataframes first.
#
# Once you run the next cell, an MEI file call "pyAMPACT-CRIM_test.mei.xml" will appear in the directory on the left at `pyAMPACT/output_files/pyAMPACT-CRIM_test.mei.xml`. It will be too big to view in colab, but if you double-click it you can download it.

# %%
cvf_table = crim_piece.cvfs()
pyamp_piece.toMEI('pyAMPACT-CRIM_test', ' ', dfs={'CVF': cvf_table}, analysis_tag='harm')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-ced119f75326> in <cell line: 1>()
# ----> 1 cvf_table = crim_piece.cvfs()
#       2 pyamp_piece.toMEI('pyAMPACT-CRIM_test', ' ', dfs={'CVF': cvf_table}, analysis_tag='harm')
#
# AttributeError: 'NoneType' object has no attribute 'cvfs'

# %% [markdown]
# pyAMPACT can also create links to short excerpts of pieces, with or without extra data. We do this in the .krn format for its character economy and extensibility, via the (Verovio Humdrum Viewer)[https://verovio.humdrum.org]. Let's look at the cadential voice functions used in the last cadence of this piece which is in the last two measures. Soon we'll have the ability to include annotations in .krn output too, and then these will optionally include the annotations. But for now, let's just look at the last two measures.

# %%
pyamp_piece.show(start=45)
# Out:
# https://verovio.humdrum.org/?t=...
