# %% [markdown]
# <a href="https://colab.research.google.com/github/jcdevaney/pyAMPACTtutorials/blob/main/Tutorial_03_pyAMPACT_symbolic_Annotations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>pyAMPACT Working with Annotations</h1>

# %%
# Due to package dependencies issues, you will have to restart the runtime
# after running this cell and then and re-run it a second time

from IPython.utils import io
# !pip install pyampact
# !pip install crim_intervals
import pyampact
import pandas as pd
import crim_intervals as crim
import numpy as np
import librosa
# Out:
# Requirement already satisfied: pyampact in /usr/local/lib/python3.11/dist-packages (0.7.9)
# Collecting music21==9.1.0 (from pyampact)
#   Using cached music21-9.1.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: pandas==2.2.0 in /usr/local/lib/python3.11/dist-packages (from pyampact) (2.2.0)
# Requirement already satisfied: pyarrow==15.0.0 in /usr/local/lib/python3.11/dist-packages (from pyampact) (15.0.0)
# Requirement already satisfied: numpy==1.24.3 in /usr/local/lib/python3.11/dist-packages (from pyampact) (1.24.3)
# Requirement already satisfied: requests==2.31.0 in /usr/local/lib/python3.11/dist-packages (from pyampact) (2.31.0)
# Requirement already satisfied: pytest==7.4.3 in /usr/local/lib/python3.11/dist-packages (from pyampact) (7.4.3)
# Requirement already satisfied: scipy==1.11.1 in /usr/local/lib/python3.11/dist-packages (from pyampact) (1.11.1)
# Requirement already satisfied: librosa==0.10.0.post2 in /usr/local/lib/python3.11/dist-packages (from pyampact) (0.10.0.post2)
# Requirement already satisfied: mido==1.3.2 in /usr/local/lib/python3.11/dist-packages (from pyampact) (1.3.2)
# Requirement already satisfied: setuptools>=48 in /usr/local/lib/python3.11/dist-packages (from pyampact) (75.2.0)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.11/dist-packages (from librosa==0.10.0.post2->pyampact) (3.0.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from librosa==0.10.0.post2->pyampact) (1.6.1)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.11/dist-packages (from librosa==0.10.0.post2->pyampact) (1.0.1)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from librosa==0.10.0.post2->pyampact) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.11/dist-packages (from librosa==0.10.0.post2->pyampact) (0.60.0)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.11/dist-packages (from librosa==0.10.0.post2->pyampact) (0.13.1)
# Requirement already satisfied: pooch<1.7,>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa==0.10.0.post2->pyampact) (1.6.0)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.11/dist-packages (from librosa==0.10.0.post2->pyampact) (0.5.0.post1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.11/dist-packages (from librosa==0.10.0.post2->pyampact) (4.13.2)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.11/dist-packages (from librosa==0.10.0.post2->pyampact) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa==0.10.0.post2->pyampact) (1.1.0)
# Requirement already satisfied: packaging~=23.1 in /usr/local/lib/python3.11/dist-packages (from mido==1.3.2->pyampact) (23.2)
# Requirement already satisfied: chardet in /usr/local/lib/python3.11/dist-packages (from music21==9.1.0->pyampact) (4.0.0)
# Requirement already satisfied: jsonpickle in /usr/local/lib/python3.11/dist-packages (from music21==9.1.0->pyampact) (4.1.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from music21==9.1.0->pyampact) (3.10.0)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.11/dist-packages (from music21==9.1.0->pyampact) (8.7.0)
# Requirement already satisfied: webcolors>=1.5 in /usr/local/lib/python3.11/dist-packages (from music21==9.1.0->pyampact) (1.11.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas==2.2.0->pyampact) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas==2.2.0->pyampact) (2021.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas==2.2.0->pyampact) (2025.2)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.11/dist-packages (from pytest==7.4.3->pyampact) (2.1.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /usr/local/lib/python3.11/dist-packages (from pytest==7.4.3->pyampact) (1.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests==2.31.0->pyampact) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests==2.31.0->pyampact) (3.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests==2.31.0->pyampact) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests==2.31.0->pyampact) (2020.12.5)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.0->librosa==0.10.0.post2->pyampact) (0.43.0)
# Requirement already satisfied: appdirs>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from pooch<1.7,>=1.0->librosa==0.10.0.post2->pyampact) (1.4.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas==2.2.0->pyampact) (1.16.0)
# Collecting joblib>=0.14 (from librosa==0.10.0.post2->pyampact)
#   Downloading joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.20.0->librosa==0.10.0.post2->pyampact) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile>=0.12.1->librosa==0.10.0.post2->pyampact) (1.17.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->music21==9.1.0->pyampact) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->music21==9.1.0->pyampact) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->music21==9.1.0->pyampact) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->music21==9.1.0->pyampact) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->music21==9.1.0->pyampact) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->music21==9.1.0->pyampact) (3.2.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa==0.10.0.post2->pyampact) (2.22)
# Using cached music21-9.1.0-py3-none-any.whl (22.8 MB)
# Downloading joblib-1.5.1-py3-none-any.whl (307 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 4.0 MB/s eta 0:00:00
# Installing collected packages: joblib, music21
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.0.1
#     Uninstalling joblib-1.0.1:
#       Successfully uninstalled joblib-1.0.1
#   Attempting uninstall: music21
#     Found existing installation: music21 8.3.0
#     Uninstalling music21-8.3.0:
#       Successfully uninstalled music21-8.3.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# crim-intervals 2.0.50 requires joblib==1.0.1, but you have joblib 1.5.1 which is incompatible.
# crim-intervals 2.0.50 requires music21==8.3.0, but you have music21 9.1.0 which is incompatible.
# Successfully installed joblib-1.5.1 music21-9.1.0
# Requirement already satisfied: crim_intervals in /usr/local/lib/python3.11/dist-packages (2.0.50)
# Requirement already satisfied: altair==5.2.0 in /usr/local/lib/python3.11/dist-packages (from crim_intervals) (5.2.0)
# Requirement already satisfied: certifi==2020.12.5 in /usr/local/lib/python3.11/dist-packages (from crim_intervals) (2020.12.5)
# Requirement already satisfied: chardet==4.0.0 in /usr/local/lib/python3.11/dist-packages (from crim_intervals) (4.0.0)
# Requirement already satisfied: h11==0.14.0 in /usr/local/lib/python3.11/dist-packages (from crim_intervals) (0.14.0)
# Requirement already satisfied: httpcore==1.0.2 in /usr/local/lib/python3.11/dist-packages (from crim_intervals) (1.0.2)
# Requirement already satisfied: httpx==0.26.0 in /usr/local/lib/python3.11/dist-packages (from crim_intervals) (0.26.0)
# Requirement already satisfied: idna==3.1 in /usr/local/lib/python3.11/dist-packages (from crim_intervals) (3.1)
# Requirement already satisfied: ipython<8.0,>=7.23.1 in /usr/local/lib/python3.11/dist-packages (from crim_intervals) (7.34.0)
# Collecting joblib==1.0.1 (from crim_intervals)
#   Using cached joblib-1.0.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: jsonschema>=3.1 in /usr/local/lib/python3.11/dist-packages (from crim_intervals) (4.23.0)
# Requirement already satisfied: lxml==5.1.0 in /usr/local/lib/python3.11/dist-packages (from crim_intervals) (5.1.0)
# Requirement already satisfied: matplotlib<4.0.0,>=3.9.2 in /usr/local/lib/python3.11/dist-packages (from crim_intervals) (3.10.0)
# Requirement already satisfied: more-itertools==8.7.0 in /usr/local/lib/python3.11/dist-packages (from crim_intervals) (8.7.0)
# Collecting music21==8.3.0 (from crim_intervals)
#   Using cached music21-8.3.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.20.2 in /usr/local/lib/python3.11/dist-packages (from crim_intervals) (1.24.3)
# Requirement already satisfied: pandas>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from crim_intervals) (2.2.0)
# Requirement already satisfied: plotly==5.19.0 in /usr/local/lib/python3.11/dist-packages (from crim_intervals) (5.19.0)
# Requirement already satisfied: plotly-express==0.4.1 in /usr/local/lib/python3.11/dist-packages (from crim_intervals) (0.4.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from crim_intervals) (15.0.0)
# Requirement already satisfied: python-dateutil==2.8.2 in /usr/local/lib/python3.11/dist-packages (from crim_intervals) (2.8.2)
# Requirement already satisfied: python-louvain==0.16 in /usr/local/lib/python3.11/dist-packages (from crim_intervals) (0.16)
# Requirement already satisfied: pytz==2021.1 in /usr/local/lib/python3.11/dist-packages (from crim_intervals) (2021.1)
# Requirement already satisfied: pyvis==0.1.9 in /usr/local/lib/python3.11/dist-packages (from crim_intervals) (0.1.9)
# Requirement already satisfied: requests==2.31.0 in /usr/local/lib/python3.11/dist-packages (from crim_intervals) (2.31.0)
# Requirement already satisfied: rfc3986==1.4.0 in /usr/local/lib/python3.11/dist-packages (from crim_intervals) (1.4.0)
# Requirement already satisfied: seaborn==0.13 in /usr/local/lib/python3.11/dist-packages (from crim_intervals) (0.13.0)
# Requirement already satisfied: six==1.16.0 in /usr/local/lib/python3.11/dist-packages (from crim_intervals) (1.16.0)
# Requirement already satisfied: sniffio==1.2.0 in /usr/local/lib/python3.11/dist-packages (from crim_intervals) (1.2.0)
# Requirement already satisfied: statsmodels==0.14.1 in /usr/local/lib/python3.11/dist-packages (from crim_intervals) (0.14.1)
# Requirement already satisfied: textdistance==4.2.1 in /usr/local/lib/python3.11/dist-packages (from crim_intervals) (4.2.1)
# Requirement already satisfied: verovio==4.1.0 in /usr/local/lib/python3.11/dist-packages (from crim_intervals) (4.1.0)
# Requirement already satisfied: webcolors==1.11.1 in /usr/local/lib/python3.11/dist-packages (from crim_intervals) (1.11.1)
# Requirement already satisfied: xlsxwriter==3.0.2 in /usr/local/lib/python3.11/dist-packages (from crim_intervals) (3.0.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from altair==5.2.0->crim_intervals) (3.1.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from altair==5.2.0->crim_intervals) (23.2)
# Requirement already satisfied: toolz in /usr/local/lib/python3.11/dist-packages (from altair==5.2.0->crim_intervals) (0.12.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx==0.26.0->crim_intervals) (4.9.0)
# Requirement already satisfied: jsonpickle in /usr/local/lib/python3.11/dist-packages (from music21==8.3.0->crim_intervals) (4.1.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly==5.19.0->crim_intervals) (9.1.2)
# Requirement already satisfied: scipy>=0.18 in /usr/local/lib/python3.11/dist-packages (from plotly-express==0.4.1->crim_intervals) (1.11.1)
# Requirement already satisfied: patsy>=0.5 in /usr/local/lib/python3.11/dist-packages (from plotly-express==0.4.1->crim_intervals) (1.0.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from python-louvain==0.16->crim_intervals) (3.4.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests==2.31.0->crim_intervals) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests==2.31.0->crim_intervals) (2.4.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython<8.0,>=7.23.1->crim_intervals) (75.2.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.11/dist-packages (from ipython<8.0,>=7.23.1->crim_intervals) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython<8.0,>=7.23.1->crim_intervals) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython<8.0,>=7.23.1->crim_intervals) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.11/dist-packages (from ipython<8.0,>=7.23.1->crim_intervals) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython<8.0,>=7.23.1->crim_intervals) (3.0.51)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython<8.0,>=7.23.1->crim_intervals) (2.19.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython<8.0,>=7.23.1->crim_intervals) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from ipython<8.0,>=7.23.1->crim_intervals) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython<8.0,>=7.23.1->crim_intervals) (4.9.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.1->crim_intervals) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.1->crim_intervals) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.1->crim_intervals) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.1->crim_intervals) (0.25.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.9.2->crim_intervals) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.9.2->crim_intervals) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.9.2->crim_intervals) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.9.2->crim_intervals) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.9.2->crim_intervals) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.9.2->crim_intervals) (3.2.3)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.2.0->crim_intervals) (2025.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython<8.0,>=7.23.1->crim_intervals) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->altair==5.2.0->crim_intervals) (3.0.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython<8.0,>=7.23.1->crim_intervals) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<8.0,>=7.23.1->crim_intervals) (0.2.13)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.11/dist-packages (from referencing>=0.28.4->jsonschema>=3.1->crim_intervals) (4.13.2)
# Using cached joblib-1.0.1-py3-none-any.whl (303 kB)
# Using cached music21-8.3.0-py3-none-any.whl (22.8 MB)
# Installing collected packages: joblib, music21
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.5.1
#     Uninstalling joblib-1.5.1:
#       Successfully uninstalled joblib-1.5.1
#   Attempting uninstall: music21
#     Found existing installation: music21 9.1.0
#     Uninstalling music21-9.1.0:
#       Successfully uninstalled music21-9.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pyampact 0.7.9 requires music21==9.1.0, but you have music21 8.3.0 which is incompatible.
# imbalanced-learn 0.13.0 requires joblib<2,>=1.1.1, but you have joblib 1.0.1 which is incompatible.
# scikit-learn 1.6.1 requires joblib>=1.2.0, but you have joblib 1.0.1 which is incompatible.
# Successfully installed joblib-1.0.1 music21-8.3.0

# %%
# !git clone https://github.com/jcdevaney/pyAMPACTtutorials.git
# Out:
# Cloning into 'pyAMPACTtutorials'...
# remote: Enumerating objects: 1016, done.
# remote: Counting objects: 100% (147/147), done.
# remote: Compressing objects: 100% (69/69), done.
# remote: Total 1016 (delta 106), reused 97 (delta 78), pack-reused 869 (from 1)
# Receiving objects: 100% (1016/1016), 147.53 MiB | 16.60 MiB/s, done.
# Resolving deltas: 100% (458/458), done.
# Updating files: 100% (554/554), done.

# %% [markdown]
# <h2>Working with Humdrum Annotations<h2>

# %% [markdown]
# **The Humdrum analysis must be in the same .krn file as the score itself**. So in addition to having as many **kern spines as there are voices in the piece, the krn file should have at least one spine of analysis data. As a reference, there are several special spine types that we have dedicated methods for reading in as pandas dataframes in pyAMPACT. This table shows which pyAMPACT Score object methods to use to get each given .krn file spine type:
#
# | Spine Type | pyAMPACT Methods |
# |----------|----------|
# | **kern | .notes(), .midiPitches() |
# | **text | .lyrics() |
# | **dyanm | .dynamics() |
# | **harm | .harm(), .harmKeys(), .romanNumeral()|
# | **function | .functions() |
# | **chord | .chords() |
# | **cdata | .cdata() |
# | Any other spine type | .getSpines('name_of_spine_type') |
#
# Here is an example of reading a **harm spine.

# %%
piece = pyampact.Score('/content/pyAMPACTtutorials/test_files/Mozart_K179_seg.krn')
piece.harm()
# Out:
# array(['I', 'I', 'I', 'I', 'I', 'I', 'V7', 'V7', 'V7', 'V7', 'V7', 'I',
#        'I', 'IV', 'IV', 'V', 'V', 'I', 'I', 'I'], dtype=object)

# %% [markdown]
# Additional parsing of .krn scores is also available. If a *function spine is in the file, you can retrieve its scoretime-aligned values with the .functions() method. For non-kern files, or for kern files without a *function spine, this method returns an empty array.

# %%
piece.functions()
# Out:
# array(['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T',
#        'P', 'P', 'D', 'D', 'T', 'T', 'T'], dtype=object)

# %% [markdown]
# Analytic information in the symbolic files can be reshaped to match the time dimesnion of `.pianoRoll()` using the `snap_to` parameter.

# %%
pianoRoll = piece.pianoRoll()
piece.harm(snap_to=pianoRoll)
# Out:
# array(['I', 'I', 'I', 'I', 'I', 'I', 'V7', 'V7', 'V7', 'V7', 'V7', 'I',
#        'I', 'IV', 'IV', 'V', 'V', 'I', 'I', 'I'], dtype=object)

# %% [markdown]
# The annotations can also be reshaped to the time dimension of `.mask()`. Since annotations are sparse with respect to the number of time points, functions automatically fill in the intermediary timepoints by repeating the last label. This behavior can be modified with the filler parameter.

# %%
mask = piece.mask(num_harmonics=4, width=1)
piece.harm(snap_to=mask)
# Out:
# array(['I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I',
#        'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I',
#        'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I',
#        'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I',
#        'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I',
#        'I', 'I', 'I', 'I', 'I', 'I', 'I', 'V7', 'V7', 'V7', 'V7', 'V7',
#        'V7', 'V7', 'V7', 'V7', 'V7', 'V7', 'V7', 'V7', 'V7', 'V7', 'V7',
#        'V7', 'V7', 'V7', 'V7', 'V7', 'V7', 'V7', 'V7', 'V7', 'V7', 'V7',
#        'V7', 'V7', 'V7', 'V7', 'V7', 'V7', 'V7', 'V7', 'V7', 'V7', 'V7',
#        'V7', 'V7', 'V7', 'V7', 'V7', 'V7', 'V7', 'V7', 'V7', 'V7', 'V7',
#        'V7', 'V7', 'V7', 'V7', 'V7', 'V7', 'V7', 'V7', 'V7', 'V7', 'V7',
#        'V7', 'V7', 'V7', 'V7', 'V7', 'V7', 'V7', 'V7', 'V7', 'V7', 'V7',
#        'V7', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I',
#        'IV', 'IV', 'IV', 'IV', 'IV', 'IV', 'IV', 'IV', 'IV', 'IV', 'IV',
#        'IV', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V',
#        'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V',
#        'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V',
#        'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'I', 'I', 'I',
#        'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I',
#        'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I',
#        'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I',
#        'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I',
#        'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I',
#        'I', 'I', 'I', 'I'], dtype=object)

# %% [markdown]
# #Working with Dezran Annotations (Dezran)

# %% [markdown]
# pyAMPACT can import .dez annotation files and link them to corresponding score data in manner consistent to the way Humdrum annotation is imported (as described above).

# %%
from pyampact import snapTo
piece = pyampact.Score('/content/pyAMPACTtutorials/test_files/K279-seg.musicxml')
rn = piece.romanNumerals(output='series', dez_path='/content/pyAMPACTtutorials/test_files/K279-seg_harmony_texture.dez')
# Out:
# /usr/local/lib/python3.11/dist-packages/music21/musicxml/xmlToM21.py:1986: MusicXMLWarning: The following exception took place in m. 1 in part Klavier linke Hand.
#   warnings.warn(
# There was an issue with the function texts so they were removed.

# %% [markdown]
# Once the annotations have been imported, they can be snapped to a pyAMPACT score representation.

# %%
snapTo(rn, pianoRoll, output='series')
# Out:
# 0.00000       I
# 1.00000       I
# 2.00000       I
# 2.25000       I
# 2.50000       I
# 2.75000       I
# 3.00000       I
# 3.50000       I
# 4.00000     ii6
# 5.00000     ii6
# 5.50000     ii6
# 6.00000      V2
# 6.33333      V2
# 6.50000      I6
# 6.66667      I6
# 7.00000     ii6
# 8.00000       I
# 9.00000       I
# 10.00000      I
# 11.00000      I
# Name: tag, dtype: object

# %%
snapTo(rn, mask, output='series')
# Out:
# 0.000000     I
# 0.041667     I
# 0.083333     I
# 0.125000     I
# 0.166667     I
#             ..
# 11.791667    I
# 11.833333    I
# 11.875000    I
# 11.916667    I
# 11.958333    I
# Name: tag, Length: 288, dtype: object

# %% [markdown]
# # Working with CRIM Annotations

# %% [markdown]
# Renaissance dissonance analysis (from the humlib dissonant tool) can also be imported using .getSpines(), pyAMPACTs generic spine importer, to get `**cdata-rdiss` spine data.
#
# Humdrum's Renaissance dissonance classification tool is part of humlib. It is accessible in the command-line Humdrum tools and in the Verovio Humdrum Viewer.

# %%
piece_url = 'https://raw.githubusercontent.com/jcdevaney/pyAMPACTtutorials/main/test_files/O_Virgo_Miserere.krn'
#piece_url = 'O_Virgo_Miserere.krn'
pyamp_piece = pyampact.Score(piece_url)
rdiss = pyamp_piece.getSpines('cdata-rdiss')
rdiss
# Out:
#       Voice Part-2 Part-3
#
# 6.0     NaN    NaN      q
# 9.0     NaN    NaN      p
# 11.0    NaN    NaN      p
# 14.0      q    NaN    NaN
# 20.0      g      s      g
# 29.0      p    NaN    NaN
# 37.0      P    NaN      P
# 59.0      P    NaN    NaN
# 67.0    NaN    NaN      P
# 71.0      a      e    NaN
# 75.0    NaN      k      P
# 77.0      P    NaN    NaN
# 79.0    NaN      P      P
# 81.0      e    NaN    NaN
# 85.0      p    NaN    NaN
# 87.0    NaN      P    NaN
# 90.0      q      q    NaN
# 107.0     P    NaN      P
# 109.0   NaN      n    NaN
# 111.0   NaN      P    NaN
# 113.0     p    NaN    NaN
# 115.0   NaN    NaN      c
# 125.0   NaN      p    NaN
# 154.0     b    NaN    NaN
# 162.0     b    NaN    NaN
# 166.0     v    NaN    NaN
# 179.0     P    NaN    NaN
# 188.0     s      g      g
# 221.0   NaN      p    NaN
# 225.0   NaN      n    NaN
# 245.0   NaN      p    NaN
# 249.0   NaN      p    NaN
# 255.0   NaN      P      P
# 265.0   NaN      P    NaN
# 270.0     w    NaN    NaN
# 279.0     n      n    NaN
# 281.0     p      p    NaN
# 283.0     p      p    NaN
# 287.0     e    NaN    NaN
# 293.0   NaN    NaN      P
# 295.0   NaN      P    NaN
# 305.0   NaN      n    NaN
# 313.0     p    NaN      P
# 315.0   NaN      P    NaN
# 318.0   NaN      Q    NaN
# 325.0   NaN    NaN      p
# 332.0     s      g      g
# 345.0     P    NaN    NaN
# 353.0     p      p    NaN
# 356.0     s      g      g

# %% [markdown]
# CRIM's CVF (Cadential Voice Function analysis) dataframe can be treated as if it's a pyAMPACT dataframe without any special treatment because the dataframe's index is time-aligned and the columnar index consists of part names.
#
# In a couple of cases, CRIM dataframes differ from this structure (for example .cadences() has different columns and .presentationTypes() has a different index and columns). In these cases, the CRIM dataframes need to be restructured before importing in pyAMPACT.
#
# The code in next cell generates an MEI file called "pyAMPACT-CRIM_test.mei.xml"  in `/` (viewable on the left under Files. It will be too big to view in Colab and should download for viewing.

# %%
crim_piece = crim.importScore(piece_url)

# %%
cvf_table = crim_piece.cvfs()
pyamp_piece.toMEI('pyAMPACT-CRIM_test', ' ', dfs={'CVF': cvf_table}, analysis_tag='harm')

# %% [markdown]
# pyAMPACT can also create links to short excerpts of pieces, with or without extra data. We do this in the .krn format for its character economy and extensibility, via the (Verovio Humdrum Viewer)[https://verovio.humdrum.org]. The following code shows the cadential voice functions used in the last cadence of this piece which is in the last two measures.

# %%
pyamp_piece.show(start=45)
# Out:
# https://verovio.humdrum.org/?t=...
